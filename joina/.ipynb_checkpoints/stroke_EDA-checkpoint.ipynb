# %%
import os
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.preprocessing import LabelEncoder

# %%
import matplotlib.pyplot as plt
import plotly
from plotly.subplots import make_subplots
import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff

# %%
os.getcwd()
# Out:
# '/Users/chiehyuc/Desktop/Risk_Factor_Analysis_of_Obstructive-Sleep_Apnea/joina'

# %%
os.chdir('/Users')

# %%
path = ('/Users/chiehyuc/Desktop/stroke_data/')
xlsx = pd.ExcelFile(path+'Stroke-cleared-with_subgroup.xlsx')
male_df = pd.read_excel(xlsx, 'Male')
female_df = pd.read_excel(xlsx, 'Female')

# %%
from pathlib import Path

filepath = Path('/Users/chiehyuc/Desktop/stroke_data/female_stroke_data.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
female_df.to_csv(filepath, index=False)

filepath = Path('/Users/chiehyuc/Desktop/stroke_data/male_stroke_data.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
male_df.to_csv(filepath, index=False)

# %%
csv_path = '/Users/chiehyuc/Desktop/stroke_data/'
male_df = pd.read_csv(csv_path + 'male_stroke_data.csv')
female_df = pd.read_csv(csv_path + 'female_stroke_data.csv')

# %%
male_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 916 entries, 0 to 915
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Second_Stroke      916 non-null    int64
#  1   age                916 non-null    int64
#  2   sex                916 non-null    int64
#  3   HLOS               916 non-null    int64
#  4   NIHSS              916 non-null    int64
#  5   tPA(0/1)           916 non-null    int64
#  6   EVT(0/1)           916 non-null    int64
#  7   HTN(0/1)           916 non-null    int64
#  8   DM(0/1)            916 non-null    int64
#  9   Dyslipidemia(0/1)  916 non-null    int64
#  10  Af(0/1)            916 non-null    int64
#  11  smoking(Y/N/Q)     916 non-null    int64
#  12  LDL                916 non-null    float64
#  13  cholesterol        916 non-null    int64
#  14  TG                 916 non-null    int64
#  15  Cre                916 non-null    float64
#  16  SGPT               916 non-null    int64
#  17  HbA1c              916 non-null    float64
#  18  MRS                916 non-null    int64
# dtypes: float64(3), int64(16)
# memory usage: 136.1 KB

# %%
female_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568 entries, 0 to 567
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Second_Stroke      568 non-null    int64
#  1   age                568 non-null    int64
#  2   sex                568 non-null    int64
#  3   HLOS               568 non-null    int64
#  4   NIHSS              568 non-null    int64
#  5   tPA(0/1)           568 non-null    int64
#  6   EVT(0/1)           568 non-null    int64
#  7   HTN(0/1)           568 non-null    int64
#  8   DM(0/1)            568 non-null    int64
#  9   Dyslipidemia(0/1)  568 non-null    int64
#  10  Af(0/1)            568 non-null    int64
#  11  smoking(Y/N/Q)     568 non-null    int64
#  12  LDL                568 non-null    float64
#  13  cholesterol        568 non-null    int64
#  14  TG                 568 non-null    int64
#  15  Cre                568 non-null    float64
#  16  SGPT               568 non-null    float64
#  17  HbA1c              568 non-null    float64
#  18  MRS                568 non-null    int64
# dtypes: float64(4), int64(15)
# memory usage: 84.4 KB

# %%
male_df.describe()
# Out:
#        Second_Stroke         age    sex        HLOS       NIHSS    tPA(0/1)  \
# count     916.000000  916.000000  916.0  916.000000  916.000000  916.000000
# mean        0.050218   66.491266    0.0   14.792576    5.775109    0.078603
# std         0.218514   12.353577    0.0   14.308566    6.774242    0.269265
#
#        smoking(Y/N/Q)        LDL   cholesterol          TG         Cre  \
# count      568.000000  568.000000   568.000000  568.000000  568.000000
# mean         0.051056  109.091549   185.822183  112.926056    1.077746
# std          0.235775   43.052176    50.949452   66.251497    1.241764
# min          0.000000   18.000000    83.000000   12.000000    0.350000
# 25%          0.000000   77.925000   152.000000   72.000000    0.650000
# 50%          0.000000  105.050000   179.000000   98.500000    0.770000
# 75%          0.000000  132.125000   216.000000  135.000000    0.992500
# max          2.000000  299.400000   391.000000  846.000000   10.840000
#
#              SGPT       HbA1c         MRS
# count  568.000000  568.000000  568.000000
# mean    25.739437    6.469014    2.628521
# std     42.953158    1.752295    1.756127
# min      7.000000    3.400000    0.000000
# 25%     14.000000    5.500000    1.000000
# 50%     19.000000    5.900000    3.000000
# 75%     27.000000    6.700000    4.000000
# max    958.000000   15.900000    6.000000

# %% [markdown]
# ## Plot prep

# %%
def plot_hist(col, bins=30, title="",xlabel="",ax=None):
    sns.histplot(col, bins=bins,ax=ax, kde=True, alpha=.4, edgecolor=(1, 1, 1, .4))
    ax.set_title(f'Histogram of {title}',fontsize=20)
    ax.set_xlabel(xlabel)

# %%
# male_df['LDL'] = male_df['LDL ']
# male_df = male_df.drop(['LDL '], axis=1)

# %%
# female_df['LDL'] = female_df['LDL ']
# female_df = female_df.drop(['LDL '], axis=1)

# %%
male_df.keys()
# Out:
# Index(['Second_Stroke', 'age', 'sex', 'HLOS', 'NIHSS', 'tPA(0/1)', 'EVT(0/1)',
#        'HTN(0/1)', 'DM(0/1)', 'Dyslipidemia(0/1)', 'Af(0/1)', 'smoking(Y/N/Q)',
#        'LDL ', 'cholesterol', 'TG', 'Cre', 'SGPT', 'HbA1c', 'MRS'],
#       dtype='object')

# %% [markdown]
# ## Male data EDA

# %%
labels = male_df['Second_Stroke'].value_counts(sort = True).index
sizes = male_df['Second_Stroke'].value_counts(sort = True)

colors = ["steelblue","lightblue"]
explode = (0.05,0) 
 
plt.figure(figsize=(6,6))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=90)

plt.title('Number of male patients with a second stroke in the dataset')
plt.show()

# %%
fig, axes = plt.subplots(1,3,figsize=(11,7),constrained_layout=True)
plot_hist(male_df.HbA1c,
          title='HbA1c',
          xlabel="Level of HbA1c",
          ax=axes[0])
plot_hist(male_df.age,
          bins=30,
          title='Age',
          xlabel='Age',
          ax=axes[1])
plot_hist(male_df.cholesterol,
          title='Level of Cholesterol', 
          xlabel='Level of cholesterol in the blood',
          ax=axes[2])

plt.show()

# %% [markdown]
# ## Female data EDA

# %%
labels = female_df['Second_Stroke'].value_counts(sort = True).index
sizes = female_df['Second_Stroke'].value_counts(sort = True)

colors = ["steelblue","lightblue"]
explode = (0.05,0) 
 
plt.figure(figsize=(6,6))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=90)

plt.title('Number of male patients with a second stroke in the dataset')
plt.show()

# %%
fig, axes = plt.subplots(1,3,figsize=(11,7),constrained_layout=True)
plot_hist(female_df.HbA1c,
          title='HbA1c',
          xlabel="Level of HbA1c",
          ax=axes[0])
plot_hist(female_df.age,
          bins=30,
          title='Age',
          xlabel='Age',
          ax=axes[1])
plot_hist(female_df.cholesterol,
          title='Level of Cholesterol', 
          xlabel='Level of cholesterol in the blood',
          ax=axes[2])

plt.show()

# %%
fig, axes = plt.subplots(1,3,figsize=(11,7),constrained_layout=True)
# fig, (ax0, ax1, ax2) = plt.subplots(nrows=1, ncols=3)

plot_hist([male_df.HbA1c, female_df.HbA1c], ax=axes[0], xlabel="Level of HbA1c")
# ax.legend(prop={'size': 7})

plot_hist([male_df.age, female_df.age], ax=axes[1],  xlabel="Age comparison")
# ax.legend(prop={'size': 7})

plot_hist([male_df.cholesterol, female_df.cholesterol], ax=axes[2], xlabel="Level of cholesterol in the blood")

# Make a multiple-histogram of data-sets with different length.
# x_multi = [np.random.randn(n) for n in [10000, 5000, 2000]]
# ax3.hist(x_multi, n_bins, histtype='bar')
# ax3.set_title('different sample sizes')

# fig.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1,3,figsize=(15,8))
# constrained_layout=True

colors = ['red', 'tan']
x = (male_df['HbA1c'], female_df['HbA1c'])
label = ['male', 'female']
axes[0].hist(x, density=True, histtype='bar', color=colors, label=label)
axes[0].legend(prop={'size': 10})
axes[0].set_title('Level of HbA1c')

x = (male_df['age'], female_df['age'])
axes[1].hist(x, density=True, histtype='bar', color=colors, label=label)
axes[1].legend(prop={'size': 10})
axes[1].set_title('Age of patients')


x = (male_df['cholesterol'], female_df['cholesterol'])
axes[2].hist(x, density=True, histtype='bar', color=colors, label=label)
axes[2].legend(prop={'size': 10})
axes[2].set_title('Level of cholesterol in the blood')
# Out:
# Text(0.5, 1.0, 'Level of cholesterol in the blood')

# %%
fig, axes = plt.subplots(1,3,figsize=(15,8))
# constrained_layout=True

colors = ['red', 'tan']

x = (male_df['HLOS'], female_df['HLOS'])
label = ['male', 'female']
axes[0].hist(x, density=True, histtype='bar', color=colors, label=label)
axes[0].legend(prop={'size': 10})
axes[0].set_title('Levels of HLOS')

x = (male_df['NIHSS'], female_df['NIHSS'])
axes[1].hist(x, density=True, histtype='bar', color=colors, label=label)
axes[1].legend(prop={'size': 10})
axes[1].set_title('Levels of NIHSS')


x = (male_df['tPA(0/1)'], female_df['tPA(0/1)'])
axes[2].hist(x, density=True, histtype='bar', color=colors, label=label)
axes[2].legend(prop={'size': 10})
axes[2].set_title('tPA(0/1)')
# Out:
# Text(0.5, 1.0, 'tPA(0/1)')

# %%
fig, axes = plt.subplots(1,3,figsize=(15,8))

x = (male_df['EVT(0/1)'], female_df['EVT(0/1)'])
label = ['male', 'female']
axes[0].hist(x, density=True, histtype='bar', color=colors, label=label)
axes[0].legend(prop={'size': 10})
axes[0].set_title('EVT(0/1)')

x = (male_df['HTN(0/1)'], female_df['HTN(0/1)'])
axes[1].hist(x, density=True, histtype='bar', color=colors, label=label)
axes[1].legend(prop={'size': 10})
axes[1].set_title('HTN(0/1)')


x = (male_df['DM(0/1)'], female_df['DM(0/1)'])
axes[2].hist(x, density=True, histtype='bar', color=colors, label=label)
axes[2].legend(prop={'size': 10})
axes[2].set_title('DM(0/1)')
# Out:
# Text(0.5, 1.0, 'DM(0/1)')

# %%
fig, axes = plt.subplots(1,3,figsize=(15,8))

x = (male_df['Af(0/1)'], female_df['Af(0/1)'])
label = ['male', 'female']
axes[0].hist(x, density=True, histtype='bar', color=colors, label=label)
axes[0].legend(prop={'size': 10})
axes[0].set_title('Af(0/1)')

x = (male_df['smoking(Y/N/Q)'], female_df['smoking(Y/N/Q)'])
axes[1].hist(x, density=True, histtype='bar', color=colors, label=label)
axes[1].legend(prop={'size': 10})
axes[1].set_title('smoking(Y/N/Q)')


x = (male_df['LDL '], female_df['LDL '])
axes[2].hist(x, density=True, histtype='bar', color=colors, label=label)
axes[2].legend(prop={'size': 10})
axes[2].set_title('LDL')
# Out:
# Text(0.5, 1.0, 'LDL')

# %%
fig, axes = plt.subplots(1,3,figsize=(15,8))

x = (male_df['cholesterol'], female_df['cholesterol'])
label = ['male', 'female']
axes[0].hist(x, density=True, histtype='bar', color=colors, label=label)
axes[0].legend(prop={'size': 10})
axes[0].set_title('cholesterol')

x = (male_df['TG'], female_df['TG'])
axes[1].hist(x, density=True, histtype='bar', color=colors, label=label)
axes[1].legend(prop={'size': 10})
axes[1].set_title('TG')


x = (male_df['Cre'], female_df['Cre'])
axes[2].hist(x, density=True, histtype='bar', color=colors, label=label)
axes[2].legend(prop={'size': 10})
axes[2].set_title('Cre')
# Out:
# Text(0.5, 1.0, 'Cre')

# %%
fig, axes = plt.subplots(1,3,figsize=(15,8))

x = (male_df['SGPT'], female_df['SGPT'])
label = ['male', 'female']
axes[0].hist(x, density=True, histtype='bar', color=colors, label=label)
axes[0].legend(prop={'size': 10})
axes[0].set_title('SGPT')

x = (male_df['HbA1c'], female_df['HbA1c'])
axes[1].hist(x, density=True, histtype='bar', color=colors, label=label)
axes[1].legend(prop={'size': 10})
axes[1].set_title('HbA1c')


x = (male_df['MRS'], female_df['MRS'])
axes[2].hist(x, density=True, histtype='bar', color=colors, label=label)
axes[2].legend(prop={'size': 10})
axes[2].set_title('MRS')
# Out:
# Text(0.5, 1.0, 'MRS')

# %%
plt.matshow(male_df.corr())
plt.show()

# %%
plt.matshow(female_df.corr())
plt.show()

# %%
corr = female_df.corr()
corr.style.background_gradient(cmap='coolwarm').set_properties(**{'font-size': '0pt'})
# Out:
# /Users/chiehyuc/opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/style.py:2742: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# /Users/chiehyuc/opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/style.py:2743: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# #T_fc057_row0_col0, #T_fc057_row1_col1, #T_fc057_row3_col3, #T_fc057_row4_col4, #T_fc057_row5_col5, #T_fc057_row6_col6, #T_fc057_row7_col7, #T_fc057_row8_col8, #T_fc057_row9_col9, #T_fc057_row10_col10, #T_fc057_row11_col11, #T_fc057_row12_col12, #T_fc057_row13_col13, #T_fc057_row14_col14, #T_fc057_row15_col15, #T_fc057_row16_col16, #T_fc057_row17_col17, #T_fc057_row18_col18 {
#   background-color: #b40426;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_fc057_row0_col1, #T_fc057_row0_col14, #T_fc057_row0_col17, #T_fc057_row15_col8 {
#   background-color: #7093f3;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_fc057_row0_col2, #T_fc057_row1_col2, #T_fc057_row2_col0, #T_fc057_row2_col1, #T_fc057_row2_col2, #T_fc057_row2_col3, #T_fc057_row2_col4, #T_fc057_row2_col5, #T_fc057_row2_col6, #T_fc057_row2_col7, #T_fc057_row2_col8, #T_fc057_row2_col9, #T_fc057_row2_col10, #T_fc057_row2_col11, #T_fc057_row2_col12, #T_fc057_row2_col13, #T_fc057_row2_col14, #T_fc057_row2_col15, #T_fc057_row2_col16, #T_fc057_row2_col17, #T_fc057_row2_col18, #T_fc057_row3_col2, #T_fc057_row4_col2, #T_fc057_row5_col2, #T_fc057_row6_col2, #T_fc057_row7_col2, #T_fc057_row8_col2, #T_fc057_row9_col2, #T_fc057_row10_col2, #T_fc057_row11_col2, #T_fc057_row12_col2, #T_fc057_row13_col2, #T_fc057_row14_col2, #T_fc057_row15_col2, #T_fc057_row16_col2, #T_fc057_row17_col2, #T_fc057_row18_col2 {
#   background-color: #000000;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_fc057_row0_col3, #T_fc057_row0_col5, #T_fc057_row3_col9, #T_fc057_row3_col15, #T_fc057_row6_col13, #T_fc057_row9_col0, #T_fc057_row12_col3, #T_fc057_row14_col1, #T_fc057_row17_col3 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_fc057_row0_col4, #T_fc057_row0_col8, #T_fc057_row1_col9, #T_fc057_row5_col7, #T_fc057_row8_col0, #T_fc057_row8_col4, #T_fc057_row15_col9, #T_fc057_row16_col12 {
#   background-color: #6180e9;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_fc057_row0_col6, #T_fc057_row7_col16, #T_fc057_row8_col5, #T_fc057_row8_col11, #T_fc057_row15_col18, #T_fc057_row16_col1, #T_fc057_row16_col3 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_fc057_row0_col7, #T_fc057_row6_col17, #T_fc057_row7_col0, #T_fc057_row12_col1, #T_fc057_row13_col3 {
#   background-color: #485fd1;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_fc057_row0_col9, #T_fc057_row3_col13, #T_fc057_row4_col11, #T_fc057_row7_col5, #T_fc057_row9_col1, #T_fc057_row14_col7, #T_fc057_row15_col13 {
#   background-color: #6788ee;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_fc057_row0_col10, #T_fc057_row7_col18, #T_fc057_row10_col7 {
#   background-color: #7597f6;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_fc057_row0_col11, #T_fc057_row6_col11, #T_fc057_row7_col12, #T_fc057_row9_col7, #T_fc057_row14_col16, #T_fc057_row16_col10 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_fc057_row0_col12, #T_fc057_row0_col13, #T_fc057_row8_col10, #T_fc057_row11_col5, #T_fc057_row11_col10, #T_fc057_row16_col7, #T_fc057_row17_col16, #T_fc057_row18_col12 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_fc057_row0_col15, #T_fc057_row6_col9, #T_fc057_row9_col10, #T_fc057_row11_col15, #T_fc057_row12_col16, #T_fc057_row13_col4, #T_fc057_row14_col3, #T_fc057_row15_col16, #T_fc057_row17_col6 {
#   background-color: #455cce;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_fc057_row0_col16, #T_fc057_row1_col0, #T_fc057_row4_col13, #T_fc057_row4_col17, #T_fc057_row5_col16, #T_fc057_row11_col3, #T_fc057_row15_col3, #T_fc057_row17_col1, #T_fc057_row18_col8, #T_fc057_row18_col11 {
#   background-color: #5470de;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_fc057_row0_col18, #T_fc057_row4_col0, #T_fc057_row4_col8, #T_fc057_row4_col15, #T_fc057_row5_col9, #T_fc057_row13_col16 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_fc057_row1_col3, #T_fc057_row9_col11, #T_fc057_row17_col7 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_fc057_row1_col4, #T_fc057_row1_col7, #T_fc057_row10_col5 {
#   background-color: #9ebeff;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_fc057_row1_col5, #T_fc057_row3_col7, #T_fc057_row8_col16, #T_fc057_row15_col17, #T_fc057_row16_col4 {
#   background-color: #6687ed;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_fc057_row1_col6 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_fc057_row1_col8, #T_fc057_row10_col15, #T_fc057_row18_col14, #T_fc057_row18_col17 {
#   background-color: #6485ec;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_fc057_row1_col10 {
#   background-color: #bfd3f6;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_fc057_row1_col11, #T_fc057_row9_col3, #T_fc057_row9_col4, #T_fc057_row9_col5, #T_fc057_row9_col6, #T_fc057_row9_col16, #T_fc057_row10_col8, #T_fc057_row10_col9, #T_fc057_row10_col12, #T_fc057_row10_col13, #T_fc057_row10_col14, #T_fc057_row10_col17, #T_fc057_row11_col1, #T_fc057_row11_col7, #T_fc057_row11_col18, #T_fc057_row12_col5, #T_fc057_row12_col15, #T_fc057_row13_col0, #T_fc057_row13_col6, #T_fc057_row13_col10 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_fc057_row1_col12, #T_fc057_row5_col0, #T_fc057_row5_col15, #T_fc057_row6_col15, #T_fc057_row13_col1, #T_fc057_row14_col18, #T_fc057_row18_col0 {
#   background-color: #4961d2;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_fc057_row1_col13, #T_fc057_row5_col17, #T_fc057_row10_col16, #T_fc057_row13_col8, #T_fc057_row17_col10 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_fc057_row1_col14, #T_fc057_row6_col7, #T_fc057_row6_col14, #T_fc057_row8_col6, #T_fc057_row11_col0, #T_fc057_row14_col0, #T_fc057_row18_col16 {
#   background-color: #516ddb;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_fc057_row1_col15, #T_fc057_row3_col12 {
#   background-color: #688aef;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_fc057_row1_col16, #T_fc057_row6_col8, #T_fc057_row17_col5 {
#   background-color: #445acc;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_fc057_row1_col17, #T_fc057_row9_col15, #T_fc057_row15_col0 {
#   background-color: #465ecf;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_fc057_row1_col18, #T_fc057_row5_col6, #T_fc057_row10_col1, #T_fc057_row10_col18 {
#   background-color: #bcd2f7;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_fc057_row3_col0, #T_fc057_row12_col4, #T_fc057_row14_col4 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_fc057_row3_col1, #T_fc057_row10_col3, #T_fc057_row11_col12 {
#   background-color: #93b5fe;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_fc057_row3_col4 {
#   background-color: #d4dbe6;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_fc057_row3_col5 {
#   background-color: #8db0fe;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_fc057_row3_col6 {
#   background-color: #aec9fc;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_fc057_row3_col8, #T_fc057_row3_col17, #T_fc057_row5_col13, #T_fc057_row18_col15 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_fc057_row3_col10 {
#   background-color: #abc8fd;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_fc057_row3_col11, #T_fc057_row16_col13 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_fc057_row3_col14, #T_fc057_row7_col15, #T_fc057_row15_col4, #T_fc057_row15_col7, #T_fc057_row17_col0 {
#   background-color: #6282ea;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_fc057_row3_col16, #T_fc057_row7_col6, #T_fc057_row8_col3, #T_fc057_row11_col4, #T_fc057_row11_col6, #T_fc057_row18_col13 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_fc057_row3_col18, #T_fc057_row18_col3 {
#   background-color: #e7d7ce;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_fc057_row4_col1, #T_fc057_row15_col14 {
#   background-color: #a6c4fe;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_fc057_row4_col3, #T_fc057_row14_col13, #T_fc057_row18_col1 {
#   background-color: #ccd9ed;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_fc057_row4_col5 {
#   background-color: #bed2f6;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_fc057_row4_col6, #T_fc057_row13_col9 {
#   background-color: #ebd3c6;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_fc0

# %%
import seaborn as sns

f, ax = plt.subplots(figsize=(20, 20))
corr = male_df.corr()
sns.heatmap(corr,
    cmap=sns.diverging_palette(240, 10, as_cmap=True),
    vmin=0, vmax=1.0,
#     vmin=-1.0, vmax=1.0,
    square=True, ax=ax)
# Out:
# <AxesSubplot:>

# %%
import seaborn as s

#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_f4397_row3_col17, #T_f4397_row7_col17, #T_f4397_row8_col13, #T_f4397_row9_col8, #T_f4397_row16_col4 {
#   background-color: #5977e3;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_f4397_row3_col18, #T_f4397_row18_col3 {
#   background-color: #eed0c0;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_f4397_row4_col0, #T_f4397_row5_col0, #T_f4397_row8_col12, #T_f4397_row11_col18 {
#   background-color: #536edd;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_f4397_row4_col3 {
#   background-color: #d7dce3;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_f4397_row4_col5, #T_f4397_row17_col14 {
#   background-color: #bad0f8;
#   color:

# %%
from copy import copy

df = male_df
#your correlation array
corr = df.corr().to_numpy()
print(corr)

#conditions for filtering 0.6<=r<=0.9
val_min = 0.6
val_max = 0.99

#plotting starts here
sns.set(font_scale=2.4)
#two axis objects just for comparison purposes
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,8))

#define the colormap with clipping values
my_cmap = copy(plt.cm.YlGnBu)
my_cmap.set_over("white")
my_cmap.set_under("white")

#ax1 - full set of conditions as in the initial version 
g1 = sns.heatmap(corr,
    xticklabels=labels,
    yticklabels=labels,
    vmin=val_min,
    vmax=val_max,
    cmap=my_cmap,
    linewidths=1.0,
    linecolor="grey",
    ax=ax1)

g1.set_title("Entire heatmap")

#ax2 - remove empty rows/columns
# use only lower triangle
corr = np.tril(corr)

#delete columns where all elements do not fulfill the conditions
ind_x,  = np.where(np.all(np.logical_or(corr<val_min, corr>val_max), axis=0))
corr = np.delete(corr, ind_x, 1)
#update x labels
map_labels_x = [item for i, item in enumerate(labels) if i not in ind_x]
    
#now the same for rows 
ind_y, = np.where(np.all(np.logical_or(corr<val_min, corr>val_max), axis=1))
corr = np.delete(corr, ind_y, 0)
#update y labels
map_labels_y = [item for i, item in enumerate(labels) if i not in ind_y]

#plot heatmap
g2 = sns.heatmap(corr,
    xticklabels=map_labels_x,
    yticklabels=map_labels_y,
    vmin=val_min,
    vmax=val_max,
    cmap=my_cmap,
    linewidths=1.0,
    linecolor="grey", ax=ax2)

g2.set_title("Reduced heatmap")

plt.show()
# Out:
# [[ 1.00000000e+00  2.32397283e-02             nan  2.50069356e-02
#    6.89947813e-03  7.13783739e-03 -1.05714288e-02  5.90695038e-02
#    1.15784928e-01 -4.14933230e-03 -1.11832915e-03  8.64675490e-02
#   -6.50864806e-02 -5.83016104e-02 -2.10101445e-02  3.21827653e-02
#   -7.75867465e-02  6.96160224e-02  6.51801855e-02]
#  [ 2.32397283e-02  1.00000000e+00             nan  1.48904151e-01
#    1.48723850e-01  3.14192497e-02  5.42686091e-02  1.44695335e-01
#    8.40412629e-02 -7.93921126e-02  2.13698548e-01 -1.17578375e-01
#   -1.53808915e-01 -1.63641801e-01 -2.50005182e-01  1.10600741e-02
#   -2.27598083e-01 -4.95226289e-02  2.40548955e-01]
#  [            nan             nan             nan             nan
#               nan             nan             nan             nan
#               nan             nan             nan             nan
#               nan             nan             n